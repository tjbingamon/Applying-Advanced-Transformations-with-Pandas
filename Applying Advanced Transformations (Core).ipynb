# %% [markdown]
# # The Task
#
# #### Your task is two-fold:
#
# I. Clean the files and combine them into one final DataFrame.
#
# #### This dataframe should have the following columns:
# - Hero (Just the name of the Hero)
# - Publisher
# - Gender
# - Eye color
# - Race
# - Hair color
# - Height (numeric)
# - Skin color
# - Alignment
# - Weight (numeric)
# - Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
# - Agility
# - Flight
# - Superspeed
# etc.
# - Hint: There is a space in "100 kg" or "52.5 cm"
#
#
#
# #### II. Use your combined DataFrame to answer the following questions.
#
# 1. Compare the average weight of super powers who have Super Speed to those who do not.
# 2. What is the average height of heroes for each publisher?

# %% [markdown]
# # Import Libraries

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os, json

from matplotlib.ticker import StrMethodFormatter
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
super_info = pd.read_csv("Data/superhero_info - superhero_info.csv")
super_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
strength = pd.read_csv("Data/superhero_powers - superhero_powers.csv")
strength.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# # Clean Data and Combine

# %%
super_info.info
# Out:
# <bound method DataFrame.info of                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# ...

# %%
strength.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %% [markdown]
# # Super_Info Data

# %% [markdown]
# ### Split 'Hero|Publisher' Column

# %%
super_info[['Hero', 'Publisher']] = super_info['Hero|Publisher'].str.split('|', expand=True)
super_info
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
# drop original column
super_info.drop(columns='Hero|Publisher', inplace=True)
super_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %% [markdown]
# ### Set 'Hero' and 'Publisher' as First and Second Column

# %%
super_info = super_info[['Hero', 'Publisher', 'Gender', 'Race', 'Alignment', 'Hair color', 'Eye color', 'Skin color', 'Measurements']]
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}

# %% [markdown]
# ### Split 'Measurements' Column

# %%
type(super_info['Measurements'][0])
# Out:
# str

# %%
super_info['Measurements'] = super_info['Measurements'].str.replace("'", '"')
super_info['Measurements']
# Out:
# 0      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 1       {"Height": "191.0 cm", "Weight": "65.0 kg"}
# 2       {"Height": "185.0 cm", "Weight": "90.0 kg"}
# 3      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 4      {"Height": "193.0 cm", "Weight": "122.0 kg"}
#                            ...
# 458     {"Height": "183.0 cm", "Weight": "83.0 kg"}
# 459     {"Height": "165.0 cm", "Weight": "52.0 kg"}
# 460      {"Height": "66.0 cm", "Weight": "17.0 kg"}
# 461     {"Height": "170.0 cm", "Weight": "57.0 kg"}
# 462     {"Height": "185.0 cm", "Weight": "81.0 kg"}
# Name: Measurements, Length: 463, dtype: object

# %%
super_info['Measurements'] = super_info['Measurements'].apply(json.loads)
super_info['Measurements'].head(2)
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# Name: Measurements, dtype: object

# %%
# Measurements converted to dict
type(super_info['Measurements'][0])
# Out:
# dict

# %%
height_weight = super_info['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
super_info = pd.concat((super_info, height_weight), axis=1)
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#      Height    Weight
# 0  203.0 cm  441.0 kg
# 1  191.0 cm   65.0 kg

# %% [markdown]
# ### Drop "Measurements" column

# %%
super_info.drop(columns='Measurements', inplace=True)
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color    Height    Weight
# 0    yellow    Unknown  203.0 cm  441.0 kg
# 1      blue       blue  191.0 cm   65.0 kg

# %% [markdown]
# ### Convert 'Height' and 'Weight' to Numeric Type

# %%
super_info.rename(columns={'Height': 'Height (cm)', 'Weight': 'Weight (kg)'},
              inplace=True)
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color Height (cm) Weight (kg)
# 0    yellow    Unknown    203.0 cm    441.0 kg
# 1      blue       blue    191.0 cm     65.0 kg

# %% [markdown]
# ### Height

# %%
type(super_info['Height (cm)'][0])
# Out:
# str

# %%
# remove empty space and 'cm' from 'Height (cm)'

to_replace = [' ', 'cm']

for char in to_replace:
    super_info['Height (cm)'] = super_info['Height (cm)'].str.replace(char, '', regex=False)
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color Height (cm) Weight (kg)
# 0    yellow    Unknown       203.0    441.0 kg
# 1      blue       blue       191.0     65.0 kg

# %%
type(super_info['Height (cm)'][0])
# Out:
# str

# %%
super_info['Height (cm)'] = super_info['Height (cm)'].astype('float')
type(super_info['Height (cm)'][0])
# Out:
# numpy.float64

# %% [markdown]
# ### Weight

# %%
type(super_info['Weight (kg)'][0])
# Out:
# str

# %%
# remove empty space and 'kg' from 'Weight (kg)'

to_replace = [' ', 'kg']

for char in to_replace:
    super_info['Weight (kg)'] = super_info['Weight (kg)'].str.replace(char, '', regex=False)
super_info.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color  Height (cm) Weight (kg)
# 0    yellow    Unknown        203.0       441.0
# 1      blue       blue        191.0        65.0

# %%
# check data type
super_info['Weight (kg)'] = super_info['Weight (kg)'].astype('float')
type(super_info['Weight (kg)'][0])
# Out:
# numpy.float64

# %% [markdown]
# # Strength DataFrame

# %%
strength.head(2)
# Out:
#   hero_names                                             Powers
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...

# %%
# check data type
print(type(strength['Powers'][0]))
strength['Powers'][0]
# Out:
# <class 'str'>
# 'Agility,Super Strength,Stamina,Super Speed'

# %% [markdown]
# ### Convert 'Powers' column

# %%
strength['Powers_Split'] = strength['Powers'].str.split(',')

# %%
strength.head(2)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#                                         Powers_Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...

# %%
print(type(strength['Powers_Split'][0]))
strength['Powers_Split']
# Out:
# <class 'list'>
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers_Split, Length: 667, dtype: object

# %% [markdown]
# ### One-Hot-Encode abilities in the "Powers" column

# %%
strength['Powers_Split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
# expand the column
expand = strength.explode('Powers_Split')
expand.head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_Split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## dropping null values first
## saving the unique values from the expanded column
cols_to_make = expand['Powers_Split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
# making new column for each unique power from 'Power_Split' column
# checking with original 'Powers' column for True or False

for col in cols_to_make:
    strength[col] = strength['Powers'].str.contains(col)
strength.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# ...

# %%
strength.drop(columns=['Powers', 'Powers_Split'], inplace=True)
strength.head(2)
# Out:
#   hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0    3-D Man     True            True     True         True
# 1     A-Bomb    False            True     True        False
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# 1  ...            False        False       False              False
#
#    Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 0       False       False          False               False    False
# 1       False       False          False               False    False
#
#    Changing Armor
# 0           False
# 1           False
#
# [2 rows x 168 columns]

# %% [markdown]
# # Combine Both Datasets

# %%
df = pd.merge(super_info, strength, left_on='Hero', right_on='hero_names')
df.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color  Height (cm)  Weight (kg)  ... Weather Control  \
# 0    yellow    Unknown        203.0        441.0  ...           False
# 1      blue       blue        191.0         65.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False       False              False       False       False
# 1        False       False              False       False       False
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0          False               False    False           False
# 1          False               False    False           False
#
# [2 rows x 178 columns]

# %% [markdown]
# ### Drop "Hero_Names" column.

# %%
df.drop(columns='hero_names', inplace=True)
df.head(2)
# Out:
#          Hero          Publisher Gender           Race Alignment Hair color  \
# 0      A-Bomb      Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien  Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color  Height (cm)  Weight (kg)  ...  Weather Control  \
# 0    yellow    Unknown        203.0        441.0  ...            False
# 1      blue       blue        191.0         65.0  ...            False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False       False              False       False       False
# 1        False       False              False       False       False
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0          False               False    False           False
# 1          False               False    False           False
#
# [2 rows x 177 columns]

# %% [markdown]
# # Part 2

# %% [markdown]
# ### 1. Compare the average weight of super powers (heroes?) who have Super Speed to those who do not.

# %%
np.where(cols_to_make == 'Super Speed')
# Out:
# (array([3]),)

# %%
hero_speed = df['Super Speed'] == True
df_speed = df[hero_speed]
df_speed
# Out:
#              Hero      Publisher  Gender               Race Alignment  \
# 3     Abomination  Marvel Comics    Male  Human / Radiation       bad
# 5    Adam Strange      DC Comics    Male              Human      good
# 8      Air-Walker  Marvel Comics    Male            Unknown       bad
# 9            Ajax  Marvel Comics    Male             Cyborg       bad
# 10     Alan Scott      DC Comics    Male            Unknown      good
# ..            ...            ...     ...                ...       ...
# 453   Wonder Girl      DC Comics  Female           Demi-God      good
# 454    Wonder Man  Marvel Comics    Male            Unknown      good
# 455  Wonder Woman      DC Comics  Female             Amazon      good
# 460          Yoda   George Lucas    Male     Yoda's species      good
# 462          Zoom      DC Comics    Male            Unknown       bad
#
#     Hair color Eye color Skin color  Height (cm)  Weight (kg)  ...  \
# ...

# %%
no_speed = df[~hero_speed]
no_speed
# Out:
#                 Hero          Publisher  Gender            Race Alignment  \
# 0             A-Bomb      Marvel Comics    Male           Human      good
# 1         Abe Sapien  Dark Horse Comics    Male   Icthyo Sapien      good
# 2           Abin Sur          DC Comics    Male         Ungaran      good
# 4      Absorbing Man      Marvel Comics    Male           Human       bad
# 6          Agent Bob      Marvel Comics    Male           Human      good
# ..               ...                ...     ...             ...       ...
# 456             X-23      Marvel Comics  Female  Mutant / Clone      good
# 457            X-Man      Marvel Comics    Male         Unknown      good
# 458     Yellowjacket      Marvel Comics    Male           Human      good
# 459  Yellowjacket II      Marvel Comics  Female           Human      good
# 461          Zatanna          DC Comics  Female           Human      good
#
#            Hair color Eye color Skin color  Height (cm)  Weight (kg)  ...  \
# ...

# %%
avg_speed_weight = speed['Weight (kg)'].mean().round(2)
avg_not_speed_weight = no_speed['Weight (kg)'].mean().round(2)
print(avg_speed_weight)
print(avg_not_speed_weight)
# Out:
# 129.4
# 101.77

# %%
print(f'The average weight (kg) for Super Heroes that have "Super Speed" is \
{avg_speed_weight} compared to the average weight of Super Heroes that don\'t \
{avg_not_speed_weight}')
print(f'On average, "Super Speed" Super Heroes weigh \
{(avg_speed_weight-avg_not_speed_weight).round(2)} kg \
more.')
# Out:
# The average weight (kg) for Super Heroes that have "Super Speed" is 129.4 compared to the average weight of Super Heroes that don't 101.77
# On average, "Super Speed" Super Heroes weigh 27.63 kg more.

# %%
speed_dict = {'Have Super Speed': avg_speed_weight,
             'Do Not Have Super Speed': avg_not_speed_weight}

# %%
plt.bar(speed_dict.keys(), speed_dict.values())
plt.xlabel('Fast or Slow')
plt.ylabel('Average Weight (kg)')
plt.title('Average Weight (kg) of Fast and Slow Super Heroes');

# %% [markdown]
# ### 2. What is the average height of heroes for each publisher?

# %%
publisher_height = df.groupby('Publisher')['Height (cm)'].mean().sort_values(ascending=False)
publisher_height
# Out:
# Publisher
# Image Comics         211.000000
# Marvel Comics        191.546128
# DC Comics            181.923913
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Dark Horse Comics    176.909091
# Shueisha             171.500000
# George Lucas         159.600000
# Name: Height (cm), dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax = plt.bar(publisher_height.index, publisher_height.values)
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.xlabel('Publisher')
plt.ylabel('Average Height (cm)')
plt.title('Average Height (cm) per Publisher');
